# %%
from github import Github
import subprocess
import shutil
import os

# %%
# Create a GitHub instance using a personal access token
g = Github("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")

# Create a new repository
user = g.get_user()
repo = user.create_repo("TESTER_TESTER")

# %%
# CREATE REPO
def copy_contents(src, dst):
    # Ensure the source directory exists
    if not os.path.exists(src):
        print(f"Source directory {src} does not exist.")
        return

    # Ensure the destination directory exists
    if not os.path.exists(dst):
        os.makedirs(dst)

    # Copy each file and subdirectory from src to dst
    for item in os.listdir(src):
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        if os.path.isdir(s):
            shutil.copytree(s, d, dirs_exist_ok=True)  # dirs_exist_ok is available from Python 3.8
        else:
            shutil.copy2(s, d)

# %%
def git_push(repo_path, commit_message):
    try:
        # Change directory to the repository
        os.chdir(repo_path)

        # Git add
        subprocess.check_call(['git', 'add', '.'])

        # Git commit
        subprocess.check_call(['git', 'commit', '-m', commit_message])

        # Git push
        subprocess.check_call(['git', 'push'])
        print("Changes pushed to GitHub.")
    except subprocess.CalledProcessError as e:
        print(f"An error occurred: {e}")

# %%
def create_battle(src,dest,reponame):

    # Example usage
    copy_contents('/path/to/source/folder', '/path/to/destination/folder')
    # Example usage
    git_push('/path/to/destination/folder', 'Update repository contents')
# Out:
#   Cell In[5], line 1
#     def create_battle():
#                         ^
# IndentationError: expected an indented block

# %%
import os
import shutil
import subprocess
from github import Github

def create_github_repo(token, repo_name):
    """Create a GitHub repository and return its git URL."""
    g = Github(token)
    user = g.get_user()
    repo = user.create_repo(repo_name)
    return repo.git_url

def copy_contents(src, dst):
    """Copy contents from src directory to dst directory."""
    if not os.path.exists(src):
        print(f"Source directory {src} does not exist.")
        return False

    if not os.path.exists(dst):
        os.makedirs(dst)

    for item in os.listdir(src):
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        if os.path.isdir(s):
            shutil.copytree(s, d, dirs_exist_ok=True)
        else:
            shutil.copy2(s, d)
    return True

def git_push(repo_path, commit_message):
    """Add, commit, and push changes to a Git repository."""
    try:
        os.chdir(repo_path)
        subprocess.check_call(['git', 'init'])
        subprocess.check_call(['git', 'add', '.'])
        subprocess.check_call(['git', 'commit', '-m', commit_message])
        subprocess.check_call(['git', 'push', '-u', 'origin', 'master'])
        print("Changes pushed to GitHub.")
    except subprocess.CalledProcessError as e:
        print(f"An error occurred: {e}")

def main():
    # Set your details here
    GITHUB_TOKEN = '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'
    REPO_NAME = 'TESTER_TESTER_2'
    SRC_FOLDER = './battle_template/'
    DEST_FOLDER = 'battles/test/'

    # Step 1: Create a new GitHub repository
    git_url = create_github_repo(GITHUB_TOKEN, REPO_NAME)
    print(f"Created GitHub repository: {git_url}")

    # Step 2: Copy contents from source to destination
    if copy_contents(SRC_FOLDER, DEST_FOLDER):
        print("Contents copied successfully.")
    else:
        print("Failed to copy contents.")
        return

    # Step 3: Push the contents to the GitHub repository
    git_push(DEST_FOLDER, 'Initial commit')

main()
# Out:
# Created GitHub repository: git://github.com/codekatabattles/TESTER_TESTER_2.git
# Contents copied successfully.
# Initialized empty Git repository in /Users/askemeineche/Documents/ITU/semester_3/SE/SoftwareEngineering/Implementation/battles/test/.git/
# [main (root-commit) dde9eea] Initial commit
#  Committer: Aske Meineche <askemeineche@Askes-MacBook-Pro.local>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly. Run the
# following command and follow the instructions in your editor to edit
# your configuration file:
#
#     git config --global --edit
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  3 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 actions/.gitkeep
#  create mode 100644 main/.gitkeep
#  create mode 100644 test_files/.gitkeep
# An error occurred: Command '['git', 'push', '-u', 'origin', 'master']' returned non-zero exit status 1.
# error: src refspec master does not match any
# error: failed to push some refs to 'origin'

# %%
# !pwd
# Out:
# /Users/askemeineche/Documents/ITU/semester_3/SE/SoftwareEngineering/Implementation

# %%
import os
import shutil
from github import Github, InputGitTreeElement

class GitHubRepoManager:
    def __init__(self, github_token, src_folder, dest_folder):
        self.github = Github(github_token)
        self.src_folder = src_folder
        self.dest_folder = dest_folder

    def create_repo(self, repo_name):
        """Create a GitHub repository and return its git URL."""
        user = self.github.get_user()
        repo = user.create_repo(repo_name)
        return repo

    def copy_contents(self):
        """Copy contents from src directory to dest directory."""
        if not os.path.exists(self.src_folder):
            raise FileNotFoundError(f"Source directory {self.src_folder} does not exist.")

        if not os.path.exists(self.dest_folder):
            os.makedirs(self.dest_folder)

        for item in os.listdir(self.src_folder):
            src_path = os.path.join(self.src_folder, item)
            dest_path = os.path.join(self.dest_folder, item)
            if os.path.isdir(src_path):
                shutil.copytree(src_path, dest_path, dirs_exist_ok=True)
            else:
                shutil.copy2(src_path, dest_path)

    def push_to_repo(self, repo, branch, commit_message, author):
        """Push contents of the dest_folder to the specified GitHub repository."""
        try:
            #commit = repo.get_branch(branch).commit
            print(repo.default_branch)
            default_branch = repo.get_branch(repo.default_branch)
            commit = default_branch.commit
            repo.create_git_ref(ref=f'refs/heads/{branch}', sha=commit.sha)
        except Exception as e:
            # Branch doesn't exist, so let's create it based on the default branch
            default_branch = repo.get_branch(repo.default_branch)
            commit = default_branch.commit
            repo.create_git_ref(ref=f'refs/heads/{branch}', sha=commit.sha)

        master_ref = repo.get_git_ref(f'heads/{branch}')
        base_tree = commit.commit.tree
        element_list = []

        for entry in os.listdir(self.dest_folder):
            with open(os.path.join(self.dest_folder, entry), 'rb') as input_file:
                data = input_file.read()
            element = InputGitTreeElement(entry, '100644', 'blob', data.decode("utf-8"))
            element_list.append(element)

        tree = repo.create_git_tree(element_list, base_tree)
        parent = repo.get_git_commit(commit.sha)
        commit = repo.create_git_commit(commit_message, tree, [parent], author=author, committer=author)
        master_ref.edit(commit.sha)

# Example usage
github_token = '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'
src_folder = './battle_template'
dest_folder = 'battles/test'
repo_name = 'TESTER_TESTER13'
repo_manager = GitHubRepoManager(github_token, src_folder, dest_folder)

# Create a repository
repo = repo_manager.create_repo(repo_name)
print(f"Created GitHub repository: {repo.git_url}")

# Copy contents from source to destination folder
repo_manager.copy_contents()

# Push to GitHub repository
author_info = {'name': 'codekatabattles', 'email': 'codekatabattles@gmail.com'}
repo_manager.push_to_repo(repo,"main", 'Initial commit', author_info)
# Out:
# Created GitHub repository: git://github.com/codekatabattles/TESTER_TESTER13.git
# main
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# Cell In[35], line 38, in GitHubRepoManager.push_to_repo(self, repo, branch, commit_message, author)
#      37 print(repo.default_branch)
# ---> 38 default_branch = repo.get_branch(repo.default_branch)
#      39 commit = default_branch.commit
#
# File ~/Library/Python/3.9/lib/python/site-packages/github/Repository.py:2003, in Repository.get_branch(self, branch)
#    2002 assert isinstance(branch, str), branch
# -> 2003 headers, data = self._requester.requestJsonAndCheck("GET", f"{self.url}/branches/{branch}")
#    2004 return github.Branch.Branch(self._requester, headers, data, completed=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/github/Requester.py:494, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     486 def requestJsonAndCheck(
#     487     self,
#     488     verb: str,
#    (...)
#     492     input: Optional[Any] = None,
#     493 ) -> Tuple[Dict[str, Any], Any]:
# --> 494     return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#
# File ~/Library/Python/3.9/lib/python/site-packages/github/Requester.py:525, in Requester.__check(self, status, responseHeaders, output)
#     524 if status >= 400:
# --> 525     raise self.createException(status, responseHeaders, data)
#     526 return responseHeaders, data
#
# GithubException: 404 {"message": "Branch not found", "documentation_url": "https://docs.github.com/rest/branches/branches#get-a-branch"}
#
# During handling of the above exception, another exception occurred:
#
# GithubException                           Traceback (most recent call last)
# Cell In[35], line 78
#      76 # Push to GitHub repository
#      77 author_info = {'name': 'codekatabattles', 'email': 'codekatabattles@gmail.com'}
# ---> 78 repo_manager.push_to_repo(repo,"main", 'Initial commit', author_info)
#
# Cell In[35], line 43, in GitHubRepoManager.push_to_repo(self, repo, branch, commit_message, author)
#      40     repo.create_git_ref(ref=f'refs/heads/{branch}', sha=commit.sha)
#      41 except Exception as e:
#      42     # Branch doesn't exist, so let's create it based on the default branch
# ---> 43     default_branch = repo.get_branch(repo.default_branch)
#      44     commit = default_branch.commit
#      45     repo.create_git_ref(ref=f'refs/heads/{branch}', sha=commit.sha)
#
# File ~/Library/Python/3.9/lib/python/site-packages/github/Repository.py:2003, in Repository.get_branch(self, branch)
#    1997 """
#    1998 :calls: `GET /repos/{owner}/{repo}/branches/{branch} <https://docs.github.com/en/rest/reference/repos#get-a-branch>`_
#    1999 :param branch: string
#    2000 :rtype: :class:`github.Branch.Branch`
#    2001 """
#    2002 assert isinstance(branch, str), branch
# -> 2003 headers, data = self._requester.requestJsonAndCheck("GET", f"{self.url}/branches/{branch}")
#    2004 return github.Branch.Branch(self._requester, headers, data, completed=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/github/Requester.py:494, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     486 def requestJsonAndCheck(
#     487     self,
#     488     verb: str,
#    (...)
#     492     input: Optional[Any] = None,
#     493 ) -> Tuple[Dict[str, Any], Any]:
# --> 494     return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#
# File ~/Library/Python/3.9/lib/python/site-packages/github/Requester.py:525, in Requester.__check(self, status, responseHeaders, output)
#     523 data = self.__structuredFromJson(output)
#     524 if status >= 400:
# --> 525     raise self.createException(status, responseHeaders, data)
#     526 return responseHeaders, data
#
# GithubException: 404 {"message": "Branch not found", "documentation_url": "https://docs.github.com/rest/branches/branches#get-a-branch"}

# %%
import os
import shutil
import subprocess
from github import Github, InputGitTreeElement

class GitHubRepoManager:
    def __init__(self, github_token, src_folder, dest_folder):
        self.github = Github(github_token)
        self.src_folder = src_folder
        self.dest_folder = dest_folder
        self.original_dir = os.getcwd()
        subprocess.run(['git', 'config', '--global', 'http.postBuffer', '524288000'], check=True)


    def create_repo(self, repo_name):
        """Create a GitHub repository and return its git URL."""
        user = self.github.get_user()
        repo = user.create_repo(repo_name)
        return repo

    def copy_contents(self):
        """Copy contents from src directory to dest directory."""
        if not os.path.exists(self.src_folder):
            raise FileNotFoundError(f"Source directory {self.src_folder} does not exist.")
        if not os.path.exists(self.dest_folder):
            os.makedirs(self.dest_folder)
        for item in os.listdir(self.src_folder):
            src_path = os.path.join(self.src_folder, item)
            dest_path = os.path.join(self.dest_folder, item)
            if os.path.isdir(src_path):
                shutil.copytree(src_path, dest_path, dirs_exist_ok=True)
            else:
                shutil.copy2(src_path, dest_path)

    def git_config_user(self, repo_path, user_name, user_email):
        """Configure the local Git user for the repository."""
        subprocess.run(['git', '-C', repo_path, 'config', 'user.name', user_name], check=True)
        subprocess.run(['git', '-C', repo_path, 'config', 'user.email', user_email], check=True)

    def push_to_repo(self, repo_path, commit_message, branch='main', user_name='Your Name', user_email='your_email@example.com'):
        """Add, commit, and push changes to the specified GitHub repository."""
        try:
            # Save the current directory and change to the repository directory
            original_dir = os.getcwd()
            os.chdir(repo_path)

            # Configure the local Git user
            self.git_config_user(repo_path, user_name, user_email)

            # Git operations
            subprocess.run(['git', 'init'], check=True)
            subprocess.run(['git', 'add', '.'], check=True)
            subprocess.run(['git', 'commit', '-m', commit_message], check=True)
            subprocess.run(['git', 'remote', 'add', 'origin', repo.git_url], check=True)
            subprocess.run(['git', 'push', '-u', 'origin', branch], check=True)
            print("Changes pushed to GitHub.")
        except subprocess.CalledProcessError as e:
            print(f"An error occurred: {e}")
        finally:
            # Change back to the original directory
            os.chdir(original_dir)

# Example usage
abs_path = "/Users/askemeineche/Documents/ITU/semester_3/SE/SoftwareEngineering/Implementation/"
github_token = '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'
src_folder = abs_path+'battle_template/'
dest_folder = abs_path+'battles/test4/'
repo_name = 'TESTER7'

repo_manager = GitHubRepoManager(github_token, src_folder, dest_folder)

# Create a repository
repo = repo_manager.create_repo(repo_name)
print(f"Created GitHub repository: {repo.git_url}")

# Copy contents from source to destination folder
repo_manager.copy_contents()

# Push to GitHub repository
author_info = {'name': 'codekatabattles', 'email': 'codekatabattles@gmail.com'}
repo_manager.push_to_repo(dest_folder, 'Initial commit', 'main', author_info['name'], author_info['email'])
# Out:
# Created GitHub repository: git://github.com/codekatabattles/TESTER7.git
# Initialized empty Git repository in /Users/askemeineche/Documents/ITU/semester_3/SE/SoftwareEngineering/Implementation/battles/test4/.git/
# [main (root-commit) ebc6766] Initial commit
#  Committer: Aske Meineche <askemeineche@Askes-MacBook-Pro.local>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly:
#
#     git config --global user.name "Your Name"
#     git config --global user.email you@example.com
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  3 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 actions/.gitkeep
#  create mode 100644 main/.gitkeep
#  create mode 100644 test_files/.gitkeep
# An error occurred: Command '['git', 'push', '-u', 'origin', 'main']' returned non-zero exit status 128.
# fatal: read error: Connection reset by peer

# %%
# !ls battles/test
# Out:
# actions    main       test_files

# %%
import os
import shutil
import subprocess
from github import Github, InputGitTreeElement

class GitHubRepoManager:
    def __init__(self, github_token, src_folder, dest_folder):
        self.github = Github(github_token)
        self.src_folder = src_folder
        self.dest_folder = dest_folder
        self.original_dir = os.getcwd()
        subprocess.run(['git', 'config', '--global', 'http.postBuffer', '524288000'], check=True)

    def create_repo(self, repo_name):
        """Create a GitHub repository and return its git URL."""
        user = self.github.get_user()
        repo = user.create_repo(repo_name)
        return repo

    def copy_contents(self):
        """Copy contents from src directory to dest directory."""
        if not os.path.exists(self.src_folder):
            raise FileNotFoundError(f"Source directory {self.src_folder} does not exist.")
        if not os.path.exists(self.dest_folder):
            os.makedirs(self.dest_folder)
        for item in os.listdir(self.src_folder):
            src_path = os.path.join(self.src_folder, item)
            dest_path = os.path.join(self.dest_folder, item)
            if os.path.isdir(src_path):
                shutil.copytree(src_path, dest_path, dirs_exist_ok=True)
            else:
                shutil.copy2(src_path, dest_path)

    def git_store_global_user(self):
        """Store the global Git user settings."""
        self.original_user_name = subprocess.run(['git', 'config', '--global', 'user.name'], check=True, text=True, stdout=subprocess.PIPE).stdout.strip()
        self.original_user_email = subprocess.run(['git', 'config', '--global', 'user.email'], check=True, text=True, stdout=subprocess.PIPE).stdout.strip()

    def git_set_local_user(self, repo_path, user_name, user_email):
        """Set the local Git user settings for the repository."""
        subprocess.run(['git', '-C', repo_path, 'config', 'user.name', user_name], check=True)
        subprocess.run(['git', '-C', repo_path, 'config', 'user.email', user_email], check=True)

    def git_restore_global_user(self):
        """Restore the global Git user settings."""
        subprocess.run(['git', 'config', '--global', 'user.name', self.original_user_name], check=True)
        subprocess.run(['git', 'config', '--global', 'user.email', self.original_user_email], check=True)

    def push_to_repo(self, repo_path, commit_message, branch='main', user_name='Your Name', user_email='your_email@example.com'):
        """Add, commit, and push changes to the specified GitHub repository."""
        
        original_dir = os.getcwd()
        os.chdir(repo_path)

        # Store the global Git user settings
        #self.git_store_global_user()

        # Set the local Git user settings
        self.git_set_local_user(repo_path, user_name, user_email)

        # Initialize, add, commit, and set remote
        subprocess.run(['git', 'init'], check=True)
        subprocess.run(['git', 'add', '.'], check=True)
        subprocess.run(['git', 'commit', '-m', commit_message], check=True)
        subprocess.run(['git', 'remote', 'add', 'origin', repo.git_url], check=True)
        subprocess.run(['git', 'push', '-u', 'origin', branch], check=True)
        print("Changes pushed to GitHub.")


        # Restore the global Git user settings
        #self.git_restore_global_user()
        os.chdir(original_dir)

# %%
# Example usage
abs_path = "/Users/askemeineche/Documents/ITU/semester_3/SE/SoftwareEngineering/Implementation/"
github_token = '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'
src_folder = abs_path+'battle_template/'
dest_folder = abs_path+'battles/test9/'
repo_name = 'TESTER12'
repo_manager = GitHubRepoManager(github_token, src_folder, dest_folder)

# Create a repository
repo = repo_manager.create_repo(repo_name)
print(f"Created GitHub repository: {repo.git_url}")

# Copy contents from source to destination folder
repo_manager.copy_contents()

# Push to GitHub repository
author_info = {'name': 'codekatabattles', 'email': 'codekatabattles@gmail.com'}
repo_manager.push_to_repo(dest_folder, 'Initial commit', 'main', author_info['name'], author_info['email'])
# Out:
# Created GitHub repository: git://github.com/codekatabattles/TESTER12.git
# Initialized empty Git repository in /Users/askemeineche/Documents/ITU/semester_3/SE/SoftwareEngineering/Implementation/battles/test9/.git/
# [main (root-commit) 6303aca] Initial commit
#  Committer: Aske Meineche <askemeineche@Askes-MacBook-Pro.local>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly:
#
#     git config --global user.name "Your Name"
#     git config --global user.email you@example.com
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  3 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 actions/.gitkeep
#  create mode 100644 main/.gitkeep
#  create mode 100644 test_files/.gitkeep
# fatal: read error: Connection reset by peer
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[57], line 18
#      16 # Push to GitHub repository
#      17 author_info = {'name': 'codekatabattles', 'email': 'codekatabattles@gmail.com'}
# ---> 18 repo_manager.push_to_repo(dest_folder, 'Initial commit', 'main', author_info['name'], author_info['email'])
#
# Cell In[55], line 66, in GitHubRepoManager.push_to_repo(self, repo_path, commit_message, branch, user_name, user_email)
#      64 subprocess.run(['git', 'commit', '-m', commit_message], check=True)
#      65 subprocess.run(['git', 'remote', 'add', 'origin', repo.git_url], check=True)
# ---> 66 subprocess.run(['git', 'push', '-u', 'origin', branch], check=True)
#      67 print("Changes pushed to GitHub.")
#      70 # Restore the global Git user settings
#      71 #self.git_restore_global_user()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:528, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     526     retcode = process.poll()
#     527     if check and retcode:
# --> 528         raise CalledProcessError(retcode, process.args,
#     529                                  output=stdout, stderr=stderr)
#     530 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['git', 'push', '-u', 'origin', 'main']' returned non-zero exit status 128.
